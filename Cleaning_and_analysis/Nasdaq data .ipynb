# %%
import pandas as pd

# %%
df = pd.read_csv("nasdaq_tesla_stock_data.csv")

# %%
df
# Out:
#      Unnamed: 0        Date Close/Last       Volume       Open       High  \
# 0             1  02/14/2023    $209.25  216,455,700    $191.94    $209.82
# 1             2  02/13/2023    $194.64  172,475,500   $194.415     $196.3
# 2             3  02/10/2023    $196.89  204,754,100   $202.225     $206.2
# 3             4  02/09/2023    $207.32  215,431,400   $207.775       $214
# 4             5  02/08/2023    $201.29  180,673,600     $196.1       $203
# ..          ...         ...        ...          ...        ...        ...
# 122         129  08/19/2022  $296.6666   61,395,396       $299    $300.36
# 123         130  08/18/2022    $302.87   47,500,535       $306     $306.5
# 124         131  08/17/2022  $303.9966   68,765,977  $303.3966  $309.6566
# 125         132  08/16/2022  $306.5633   88,136,319  $311.6666  $314.6666
# 126         134  08/15/2022    $309.32   89,359,179  $301.7866  $313.1333
#
#            Low
# 0      $189.44
# 1      $187.61
# 2      $192.89
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df
# Out:
#            Date Close/Last       Volume       Open       High        Low
# 0    02/14/2023    $209.25  216,455,700    $191.94    $209.82    $189.44
# 1    02/13/2023    $194.64  172,475,500   $194.415     $196.3    $187.61
# 2    02/10/2023    $196.89  204,754,100   $202.225     $206.2    $192.89
# 3    02/09/2023    $207.32  215,431,400   $207.775       $214    $204.77
# 4    02/08/2023    $201.29  180,673,600     $196.1       $203    $194.31
# ..          ...        ...          ...        ...        ...        ...
# 122  08/19/2022  $296.6666   61,395,396       $299    $300.36     $292.5
# 123  08/18/2022    $302.87   47,500,535       $306     $306.5  $301.8533
# 124  08/17/2022  $303.9966   68,765,977  $303.3966  $309.6566  $300.0333
# 125  08/16/2022  $306.5633   88,136,319  $311.6666  $314.6666  $302.8833
# 126  08/15/2022    $309.32   89,359,179  $301.7866  $313.1333    $301.23
#
# [127 rows x 6 columns]

# %%
pd.options.display.max_rows = None

# %%
df
# Out:
#            Date Close/Last       Volume       Open       High        Low
# 0    02/14/2023    $209.25  216,455,700    $191.94    $209.82    $189.44
# 1    02/13/2023    $194.64  172,475,500   $194.415     $196.3    $187.61
# 2    02/10/2023    $196.89  204,754,100   $202.225     $206.2    $192.89
# 3    02/09/2023    $207.32  215,431,400   $207.775       $214    $204.77
# 4    02/08/2023    $201.29  180,673,600     $196.1       $203    $194.31
# 5    02/07/2023    $196.81  186,010,300    $196.43     $197.5    $189.55
# 6    02/06/2023    $194.76  186,188,100    $193.01    $198.17    $189.92
# 7    02/03/2023    $189.98  232,662,000    $183.95       $199    $183.69
# 8    02/02/2023    $188.27  217,448,300   $187.325  $196.7501    $182.61
# 9    02/01/2023    $181.41  213,806,300    $173.89   $183.805    $169.93
# 10   01/31/2023    $173.22  196,813,500    $164.57     $174.3    $162.78
# 11   01/30/2023    $166.66  230,878,800    $178.05    $179.77     $166.5
# ...

# %%
df.dtypes
# Out:
# Date          datetime64[ns]
# Close/Last            object
# Volume                object
# Open                  object
# High                  object
# Low                   object
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# |

# %%
# Drop the '$' sign and convert the columns to float data type
df['Close/Last'] = df['Close/Last'].str.replace('$', '').astype(float)
df['Open'] = df['Open'].str.replace('$', '').astype(float)
df['High'] = df['High'].str.replace('$', '').astype(float)
df['Low'] = df['Low'].str.replace('$', '').astype(float)
# Out:
# /var/folders/lc/wd3z5xrd5s7cbp_lm8v3mkdm0000gn/T/ipykernel_10575/4037009723.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Close/Last'] = df['Close/Last'].str.replace('$', '').astype(float)
# /var/folders/lc/wd3z5xrd5s7cbp_lm8v3mkdm0000gn/T/ipykernel_10575/4037009723.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Open'] = df['Open'].str.replace('$', '').astype(float)
# /var/folders/lc/wd3z5xrd5s7cbp_lm8v3mkdm0000gn/T/ipykernel_10575/4037009723.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
df
# Out:
#           Date  Close/Last       Volume      Open      High       Low
# 0   2023-02-14    209.2500  216,455,700  191.9400  209.8200  189.4400
# 1   2023-02-13    194.6400  172,475,500  194.4150  196.3000  187.6100
# 2   2023-02-10    196.8900  204,754,100  202.2250  206.2000  192.8900
# 3   2023-02-09    207.3200  215,431,400  207.7750  214.0000  204.7700
# 4   2023-02-08    201.2900  180,673,600  196.1000  203.0000  194.3100
# 5   2023-02-07    196.8100  186,010,300  196.4300  197.5000  189.5500
# 6   2023-02-06    194.7600  186,188,100  193.0100  198.1700  189.9200
# 7   2023-02-03    189.9800  232,662,000  183.9500  199.0000  183.6900
# 8   2023-02-02    188.2700  217,448,300  187.3250  196.7501  182.6100
# 9   2023-02-01    181.4100  213,806,300  173.8900  183.8050  169.9300
# 10  2023-01-31    173.2200  196,813,500  164.5700  174.3000  162.7800
# 11  2023-01-30    166.6600  230,878,800  178.0500  179.7700  166.5000
# ...

# %%
df.dtypes
# Out:
# Date          datetime64[ns]
# Close/Last           float64
# Volume                object
# Open                 float64
# High                 float64
# Low                  float64
# dtype: object

# %%
df_new = df[['Date', 'Close/Last']]

# %%
df_new
# Out:
#           Date  Close/Last
# 0   2023-02-14    209.2500
# 1   2023-02-13    194.6400
# 2   2023-02-10    196.8900
# 3   2023-02-09    207.3200
# 4   2023-02-08    201.2900
# 5   2023-02-07    196.8100
# 6   2023-02-06    194.7600
# 7   2023-02-03    189.9800
# 8   2023-02-02    188.2700
# 9   2023-02-01    181.4100
# 10  2023-01-31    173.2200
# 11  2023-01-30    166.6600
# 12  2023-01-27    177.9000
# 13  2023-01-26    160.2700
# 14  2023-01-25    144.4300
# 15  2023-01-24    143.8900
# 16  2023-01-23    143.7500
# 17  2023-01-20    133.4200
# 18  2023-01-19    127.1700
# 19  2023-01-18    128.7800
# 20  2023-01-17    131.4900
# 21  2023-01-13    122.4000
# 22  2023-01-12    123.5600
# 23  2023-01-11    123.2200
# 24  2023-01-10    118.8500
# 25  2023-01-09    119.7700
# 26  2023-01-06    113.0600
# 27  2023-01-05    110.3400
# 28  2023-01-04    113.6400
# 29  2023-01-03    108.1000
# 30  2022-12-30    123.1800
# 31  2022-12-29    121.8200
# 32  2022-12-28    112.7100
# ...

# %%
df_new.to_csv("stocktesla.csv")

# %%
df_updated = df_new.drop(index=df.index[65:])

# %%
df_updated
# Out:
#          Date  Close/Last
# 0  2023-02-14      209.25
# 1  2023-02-13      194.64
# 2  2023-02-10      196.89
# 3  2023-02-09      207.32
# 4  2023-02-08      201.29
# 5  2023-02-07      196.81
# 6  2023-02-06      194.76
# 7  2023-02-03      189.98
# 8  2023-02-02      188.27
# 9  2023-02-01      181.41
# 10 2023-01-31      173.22
# 11 2023-01-30      166.66
# 12 2023-01-27      177.90
# 13 2023-01-26      160.27
# 14 2023-01-25      144.43
# 15 2023-01-24      143.89
# 16 2023-01-23      143.75
# 17 2023-01-20      133.42
# 18 2023-01-19      127.17
# 19 2023-01-18      128.78
# 20 2023-01-17      131.49
# 21 2023-01-13      122.40
# 22 2023-01-12      123.56
# 23 2023-01-11      123.22
# 24 2023-01-10      118.85
# 25 2023-01-09      119.77
# 26 2023-01-06      113.06
# 27 2023-01-05      110.34
# 28 2023-01-04      113.64
# 29 2023-01-03      108.10
# 30 2022-12-30      123.18
# 31 2022-12-29      121.82
# 32 2022-12-28      112.71
# 33 2022-12-27      109.10
# ...

# %%
df_updated.to_csv("stockteslaupdated.csv")
