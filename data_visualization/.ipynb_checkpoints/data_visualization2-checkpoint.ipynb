# %%
import pandas as pd

# %%
df_reuters = pd.read_csv("reuters_cleaned.csv")

# %%
df_reuters
# Out:
#       Unnamed: 0                                          headlines  \
# 0              0  Exclusive-To tap U.S. government billions, Tes...
# 1              1  EXCLUSIVE-To tap U.S. government billions, Tes...
# 2              2  Factbox-CCS? CHAdeMO? EV charger terms you nee...
# 3              3  FACTBOX- CCS? CHAdeMO? EV charger terms you ne...
# 4              4  Investor Gerber to run for Tesla board, cites ...
# ...          ...                                                ...
# 1150        1150  UPDATE 1-Musk's first email to Twitter staff e...
# 1151        1151  Chinese EV maker Nio posts bigger quarterly lo...
# 1152        1152  UPDATE 1-Chinese EV maker Nio posts bigger qua...
# 1153        1153  UPDATE 2-China auto sales rise at slowest pace...
# 1154        1154  ANALYSIS-Separation anxiety over Renault's fiv...
#
#                                                 extract time_stamps
# 0     ...By Jarrett Renshaw and Hyunjoo Jin(Reuters)...  2023-02-10
# ...

# %%
df_wsj = pd.read_csv("wsj_cleaned.csv")

# %%
df_wsj
# Out:
#      Unnamed: 0                                          Headlines  Timestamps
# 0             0                     FOMO Options Bets Sweep Market  2023-02-10
# 1             1  Tesla Stock Falls, Snaps Eight-Session Winning...  2023-02-10
# 2             2  WSJ Video: Is Elon Musk About to Be the World’...  2023-02-10
# 3             3      Stocks Turn Lower as 2023 Rebound Loses Steam  2023-02-09
# 4             4  Ford CEO Tells Employees They Need Clearer Goa...  2023-02-09
# ..          ...                                                ...         ...
# 423         423  Elon Musk Raises Specter of Twitter Bankruptcy...  2022-11-10
# 424         424  In California’s Wine Country, Some Towns Ban N...  2022-11-10
# 425         425  California Home Solar-Subsidy Revisions Boost ...  2022-11-10
# 426         426                  Tech Stocks Soar After CPI Report  2022-11-10
# 427         427  Layoffs Aren’t a Good Look for Big Tech’s Grow...  2022-11-10
#
# [428 rows x 3 columns]

# %%
df_ft = pd.read_csv("ft_cleaned.csv")

# %%
df_ft
# Out:
#      Unnamed: 0                                          Headlines  \
# 0             0  Tesla: resilient carmaker gives shorts $7bn he...
# 1             1  Volvo Cars’ electric sales triple despite risi...
# 2             2  Baupost chief Klarman blames Fed for ‘financia...
# 3             3  Big subsidies and ‘shovel ready’ sites: US sta...
# 4             4      Ford has bigger problems than an EV price war
# ..          ...                                                ...
# 267         267              Elon Musk bans remote work at Twitter
# 268         268  TSMC seeks neon while Sony slashes plastic Pre...
# 269         269  Cerberus in checkout line for $14bn payday Pre...
# 270         270  Psychedelics and business could make for a bad...
# 271         271  Biden says Musk security concerns ‘worthy of b...
#
#                                               excerpts  Timestamps
# 0    ...Tesla has reclaimed its spot as the most sh...  2023-02-09
# ...
